# %%
import pandas as pd

# %%
path = 'qws1_dataset/qws1.txt'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Response Time  Availability  Throughput  Successability  Reliability  \
# 0          45.00            83        27.2              50         97.4
# 1          71.75           100        14.6              88         85.5
# 2         117.00           100        23.4              83         88.0
# 3          70.00           100         5.4              83         79.3
# 4         105.20           100        18.2              80         92.2
#
#    Compliance  Best Practices  Latency  Documentation  \
# 0          89              91    43.00             58
# 1          78              80    64.42             86
# 2         100              87   111.00             59
# 3         100              75    63.00             91
# 4          78              84   104.60             91
#
#    WsRF: Web Service Relevancy Function (%)  \
# 0                                       100
# 1                                        93
# 2                                        90
# ...
